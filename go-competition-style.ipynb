# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, Flatten, Softmax, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import load_model
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch
import random

# %%
df = open('/kaggle/input/go-competition/29_Training Dataset/Training Dataset/play_style_train.csv').read().splitlines()
games = [i.split(',',2)[-1] for i in df]
game_styles = [int(i.split(',',2)[-2]) for i in df]

# %%
import os

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
chars = 'abcdefghijklmnopqrs'
coordinates = {k:v for v,k in enumerate(chars)}
coordinates
# Out:
# {'a': 0,
#  'b': 1,
#  'c': 2,
#  'd': 3,
#  'e': 4,
#  'f': 5,
#  'g': 6,
#  'h': 7,
#  'i': 8,
#  'j': 9,
#  'k': 10,
#  'l': 11,
#  'm': 12,
#  'n': 13,
#  'o': 14,
#  'p': 15,
#  'q': 16,
#  'r': 17,
#  's': 18}

# %%
# 遍历所有游戏数据
for idx, game in enumerate(games):
    num  = 16 
    moves_list = game.split(',')
    # 计算当前游戏的长度
    current_length = len(moves_list)
    # 计算需要添加的空移动数量
    if current_length < num:
        padding_length = (num - (current_length % num)) %num
        # 获取第一个动作作为padding_value
        padding_value = moves_list[0]
        # 使用列表切片添加空移动
        moves_list = [padding_value] * padding_length + moves_list
        # 更新games中的数据
        games[idx] = ','.join(moves_list)

# %%
def prepare_input_Zero(moves):
    # 初始化19x19x17的数组
    x = np.zeros((19, 19, 17))
    x_state = np.zeros((19, 19, 2))
    # 历史棋盘状态的索引
    
    history_index = 0
    num = len(moves)
    last_eight_indices = num - 8
    eight_index = moves[last_eight_indices]
    eight_color= eight_index[0]
    for move_num, move in enumerate(moves):
        color = move[0]  
        column = coordinates[move[2]]
        row = coordinates[move[3]]
        # 根据颜色设置对应的历史棋盘层
        if color == 'B':  # 黑子
            x_state[row, column, 0] = 1
        else:  # 白子
            x_state[row, column, 1] = 1
        # 在最后八个移动中，更新历史状态
        if last_eight_indices <= move_num:
            if eight_color == 'B':  # 黑子
                x[:, :, history_index * 2] = x_state[:, :, 0]
                x[:, :, history_index * 2 + 1] = x_state[:, :, 1]
            else:  # 白子
                x[:, :, history_index * 2] = x_state[:, :, 1]
                x[:, :, history_index * 2 + 1] = x_state[:, :, 0]
            history_index += 1
    # 设置当前玩家层
    if moves:
        if eight_color == 'B':  
            x[:, :, -1] = 0  # 白方
        else:
            x[:, :, -1] = 1  # 黑方
    return x

# %%
# Check how many samples can be obtained
n_games = 0
for game in games:
    n_games += 1
print(f"Total Games: {n_games}")
# Out:
# Total Games: 26615

# %%
x = []
for game in games:
    moves_list = game.split(',')
    x.append(prepare_input_Zero(moves_list))
x = np.array(x)
y = np.array(game_styles)-1

# %%
np.bincount(y)
# Out:
# array([8184, 9403, 9028])

# %%
x.shape
# Out:
# (26615, 19, 19, 17)

# %%
y_hot = tf.one_hot(y, depth=3)
y_hot = y_hot.numpy()

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_hot, test_size=0.01)

# %%
def residual_block(x, num_filters):
    # 保存輸入，用於殘差連接
    shortcut = x
    shortcut = Conv2D(num_filters*1, kernel_size=3, padding='same')(shortcut)
    # 第一個卷積層
    x = Conv2D(num_filters, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)

    # 第二個卷積層
    x = Conv2D(num_filters*1, kernel_size=3, padding='same')(x)
    # 殘差連接
    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

# %%
def create_model():
    inputs = Input(shape=(19, 19, 17))
    outputs = Conv2D(kernel_size=3, filters=256, padding='same', activation='relu')(inputs)
    for _ in range(8):  # 您可以根據需要調整殘差塊的數量
        outputs = residual_block(outputs, num_filters=256)

    outputs = Flatten()(outputs)
    outputs = Dense(4096, activation='relu')(outputs)
    outputs = Dense(1024, activation='relu')(outputs)
    outputs = Dense(3, activation='softmax', )(outputs)
    model = Model(inputs, outputs)
    opt = Adam(learning_rate=0.00005)
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 19, 19, 17)]         0         []
#
#  conv2d_33 (Conv2D)          (None, 19, 19, 256)          39424     ['input_2[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 19, 19, 256)          590080    ['conv2d_33[0][0]']
#
#  activation_24 (Activation)  (None, 19, 19, 256)          0         ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_24[0][0]']
#
#  activation_25 (Activation)  (None, 19, 19, 256)          0         ['conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_25[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 19, 19, 256)          590080    ['conv2d_33[0][0]']
#
#  add_8 (Add)                 (None, 19, 19, 256)          0         ['conv2d_37[0][0]',
#                                                                      'conv2d_34[0][0]']
#
#  activation_26 (Activation)  (None, 19, 19, 256)          0         ['add_8[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_26[0][0]']
#
#  activation_27 (Activation)  (None, 19, 19, 256)          0         ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_27[0][0]']
#
#  activation_28 (Activation)  (None, 19, 19, 256)          0         ['conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_28[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_26[0][0]']
#
#  add_9 (Add)                 (None, 19, 19, 256)          0         ['conv2d_41[0][0]',
#                                                                      'conv2d_38[0][0]']
#
#  activation_29 (Activation)  (None, 19, 19, 256)          0         ['add_9[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_29[0][0]']
#
#  activation_30 (Activation)  (None, 19, 19, 256)          0         ['conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_30[0][0]']
#
#  activation_31 (Activation)  (None, 19, 19, 256)          0         ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_31[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_29[0][0]']
#
#  add_10 (Add)                (None, 19, 19, 256)          0         ['conv2d_45[0][0]',
#                                                                      'conv2d_42[0][0]']
#
#  activation_32 (Activation)  (None, 19, 19, 256)          0         ['add_10[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_32[0][0]']
#
#  activation_33 (Activation)  (None, 19, 19, 256)          0         ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_33[0][0]']
#
#  activation_34 (Activation)  (None, 19, 19, 256)          0         ['conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_34[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_32[0][0]']
#
#  add_11 (Add)                (None, 19, 19, 256)          0         ['conv2d_49[0][0]',
#                                                                      'conv2d_46[0][0]']
#
#  activation_35 (Activation)  (None, 19, 19, 256)          0         ['add_11[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_35[0][0]']
#
#  activation_36 (Activation)  (None, 19, 19, 256)          0         ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_36[0][0]']
#
#  activation_37 (Activation)  (None, 19, 19, 256)          0         ['conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_37[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_35[0][0]']
#
#  add_12 (Add)                (None, 19, 19, 256)          0         ['conv2d_53[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  activation_38 (Activation)  (None, 19, 19, 256)          0         ['add_12[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_38[0][0]']
#
#  activation_39 (Activation)  (None, 19, 19, 256)          0         ['conv2d_55[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_39[0][0]']
#
#  activation_40 (Activation)  (None, 19, 19, 256)          0         ['conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_40[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_38[0][0]']
#
#  add_13 (Add)                (None, 19, 19, 256)          0         ['conv2d_57[0][0]',
#                                                                      'conv2d_54[0][0]']
#
#  activation_41 (Activation)  (None, 19, 19, 256)          0         ['add_13[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_41[0][0]']
#
#  activation_42 (Activation)  (None, 19, 19, 256)          0         ['conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_42[0][0]']
#
#  activation_43 (Activation)  (None, 19, 19, 256)          0         ['conv2d_60[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_43[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_41[0][0]']
#
#  add_14 (Add)                (None, 19, 19, 256)          0         ['conv2d_61[0][0]',
#                                                                      'conv2d_58[0][0]']
#
#  activation_44 (Activation)  (None, 19, 19, 256)          0         ['add_14[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_44[0][0]']
#
#  activation_45 (Activation)  (None, 19, 19, 256)          0         ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_45[0][0]']
#
#  activation_46 (Activation)  (None, 19, 19, 256)          0         ['conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_46[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_44[0][0]']
#
#  add_15 (Add)                (None, 19, 19, 256)          0         ['conv2d_65[0][0]',
#                                                                      'conv2d_62[0][0]']
#
#  activation_47 (Activation)  (None, 19, 19, 256)          0         ['add_15[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_47[0][0]']
#
#  activation_48 (Activation)  (None, 19, 19, 256)          0         ['conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_48[0][0]']
#
#  activation_49 (Activation)  (None, 19, 19, 256)          0         ['conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_49[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_47[0][0]']
#
#  add_16 (Add)                (None, 19, 19, 256)          0         ['conv2d_69[0][0]',
#                                                                      'conv2d_66[0][0]']
#
#  activation_50 (Activation)  (None, 19, 19, 256)          0         ['add_16[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_50[0][0]']
#
#  activation_51 (Activation)  (None, 19, 19, 256)          0         ['conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_51[0][0]']
#
#  activation_52 (Activation)  (None, 19, 19, 256)          0         ['conv2d_72[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_52[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 19, 19, 256)          590080    ['activation_50[0][0]']
#
#  add_17 (Add)                (None, 19, 19, 256)          0         ['conv2d_73[0][0]',
#                                                                      'conv2d_70[0][0]']
#
#  activation_53 (Activation)  (None, 19, 19, 256)          0         ['add_17[0][0]']
#
#  flatten_1 (Flatten)         (None, 92416)                0         ['activation_53[0][0]']
#
#  dense_3 (Dense)             (None, 4096)                 3785400   ['flatten_1[0][0]']
#                                                           32
#
#  dense_4 (Dense)             (None, 1024)                 4195328   ['dense_3[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    3075      ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 406381059 (1.51 GB)
# Trainable params: 406381059 (1.51 GB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=4,           
    restore_best_weights=True,  
)

# %%
from tensorflow.keras.utils import Sequence
import multiprocessing

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
class MyDataGenerator(Sequence):
    def __init__(self, games, batch_size,y):
        self.games = games
        self.y = y
        self.batch_size = batch_size
    def __len__(self):
        return int(np.ceil(len(self.games) / self.batch_size))
    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        x = self.games[start:end]
        y = self.y[start:end]

        return x, y

# %%
batch_size = 64
data_generator_train = MyDataGenerator(x_train, batch_size,y_train)
data_generator_val = MyDataGenerator(x_val, batch_size,y_val)

history = model.fit(
    data_generator_train,
    epochs = 30,
    validation_data=data_generator_val,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/30
# 396/396 [==============================] - 113s 250ms/step - loss: 1.0819 - accuracy: 0.3881 - val_loss: 1.0781 - val_accuracy: 0.3914
# Epoch 2/30
# 396/396 [==============================] - 97s 244ms/step - loss: 1.0745 - accuracy: 0.4063 - val_loss: 1.0750 - val_accuracy: 0.4260
# Epoch 3/30
# 396/396 [==============================] - 97s 244ms/step - loss: 1.0724 - accuracy: 0.4168 - val_loss: 1.0715 - val_accuracy: 0.4200
# Epoch 4/30
# 396/396 [==============================] - 97s 244ms/step - loss: 1.0696 - accuracy: 0.4149 - val_loss: 1.0691 - val_accuracy: 0.4350
# Epoch 5/30
# 396/396 [==============================] - 95s 239ms/step - loss: 1.0673 - accuracy: 0.4196 - val_loss: 1.0704 - val_accuracy: 0.4222
# Epoch 6/30
# 396/396 [==============================] - 97s 244ms/step - loss: 1.0592 - accuracy: 0.4309 - val_loss: 1.0443 - val_accuracy: 0.4651
# Epoch 7/30
# 396/396 [==============================] - 97s 244ms/step - loss: 0.9368 - accuracy: 0.5596 - val_loss: 0.8961 - val_accuracy: 0.6093
# Epoch 8/30
# 396/396 [==============================] - 96s 244ms/step - loss: 0.7824 - accuracy: 0.6703 - val_loss: 0.7577 - val_accuracy: 0.6694
# Epoch 9/30
# 396/396 [==============================] - 97s 244ms/step - loss: 0.7128 - accuracy: 0.7060 - val_loss: 0.7565 - val_accuracy: 0.6822
# Epoch 10/30
# 396/396 [==============================] - 97s 244ms/step - loss: 0.6549 - accuracy: 0.7331 - val_loss: 0.7403 - val_accuracy: 0.7092
# Epoch 11/30
# 396/396 [==============================] - 95s 239ms/step - loss: 0.5921 - accuracy: 0.7616 - val_loss: 0.7549 - val_accuracy: 0.7077
# Epoch 12/30
# 396/396 [==============================] - 95s 239ms/step - loss: 0.5211 - accuracy: 0.7910 - val_loss: 0.7977 - val_accuracy: 0.7175
# Epoch 13/30
# 396/396 [==============================] - 95s 239ms/step - loss: 0.4537 - accuracy: 0.8168 - val_loss: 0.8740 - val_accuracy: 0.6769
# Epoch 14/30
# 396/396 [==============================] - 97s 245ms/step - loss: 0.3861 - accuracy: 0.8410 - val_loss: 0.8994 - val_accuracy: 0.7025

# %%
model.save('./model_playstyle_test.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
